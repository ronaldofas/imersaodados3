# %%
import pandas as pd
# Bibliotecas dos gráficos
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# url com os dados para o exercício
url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'

# Conecta com os dados e cria uma variável com os dados para trabalho.
dados = pd.read_csv(url_dados, compression = 'zip')

# exibe o head e o tail do arquivos pandas.
dados

sns.set()
dados.rename(columns={'droga': 'composto'}, inplace=True)
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
dados_resultados = pd.read_csv('https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_resultados.csv?raw=true')
dados_resultados.head()
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %%
dados_resultados['acat_inhibitor'].unique()
# Out:
# array([0, 1])

# %%
dados_resultados['acetylcholine_receptor_agonist'].unique()
# Out:
# array([0, 1])

# %%
contagem_moa = dados_resultados.drop('id', axis=1).sum().sort_values(ascending=False)
contagem_moa
# Out:
# nfkb_inhibitor                                832
# proteasome_inhibitor                          726
# cyclooxygenase_inhibitor                      435
# dopamine_receptor_antagonist                  424
# serotonin_receptor_antagonist                 404
#                                              ...
# protein_phosphatase_inhibitor                   6
# autotaxin_inhibitor                             6
# diuretic                                        6
# erbb2_inhibitor                                 1
# atp-sensitive_potassium_channel_antagonist      1
# Length: 206, dtype: int64

# %%
dados_resultados.drop('id', axis=1).sum(axis=1)
# Out:
# 0        1
# 1        0
# 2        3
# 3        0
# 4        1
#         ..
# 23809    1
# 23810    1
# 23811    0
# 23812    1
# 23813    0
# Length: 23814, dtype: int64

# %%
dados_resultados['n_moa'] = dados_resultados.drop('id', axis=1).sum(axis=1)
dados_resultados['ativo_moa'] = (dados_resultados['n_moa'] != 0)
dados_resultados.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  n_moa  ativo_moa
# 0  id_000644bb2                            0  ...      1       True
# 1  id_000779bfc                            0  ...      0      False
# 2  id_000a6266a                            0  ...      3       True
# 3  id_0015fd391                            0  ...      0      False
# 4  id_001626bd3                            0  ...      1       True
#
# [5 rows x 209 columns]

# %%
dados_combinados = pd.merge(dados, dados_resultados[['id', 'n_moa', 'ativo_moa']], on='id')
dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ...    c-98    c-99  n_moa  ativo_moa
# 0  id_000644bb2  com_droga     24   D1  ...  0.3801  0.4176      1       True
# 1  id_000779bfc  com_droga     72   D1  ...  0.6077  0.7371      0      False
# 2  id_000a6266a  com_droga     48   D1  ... -1.4080  0.6931      3       True
# 3  id_0015fd391  com_droga     48   D1  ... -0.3876 -0.8154      0      False
# 4  id_001626bd3  com_droga     72   D2  ... -0.3786  0.7125      1       True
#
# [5 rows x 879 columns]

# %%
dados_combinados.query('tratamento == "com_controle"')
# Out:
#                  id    tratamento  tempo dose  ...    c-98    c-99  n_moa  ativo_moa
# 25     id_0054388ec  com_controle     48   D1  ...  0.8976  1.0050      0      False
# 38     id_0079af0fb  com_controle     24   D1  ...  0.6498 -1.4820      0      False
# 40     id_007bfbb91  com_controle     24   D2  ...  0.8543  0.9180      0      False
# 47     id_008a986b7  com_controle     48   D2  ... -0.9245 -0.9367      0      False
# 63     id_009d8340f  com_controle     24   D2  ... -0.4326  0.9364      0      False
# ...             ...           ...    ...  ...  ...     ...     ...    ...        ...
# 23729  id_ff1f9e5fc  com_controle     24   D1  ... -0.2422  0.0457      0      False
# 23747  id_ff469c482  com_controle     72   D1  ... -0.0742 -0.6777      0      False
# 23768  id_ff89331ca  com_controle     72   D2  ... -0.1748 -0.3626      0      False
# 23793  id_ffd26f361  com_controle     48   D2  ... -0.5272  0.7082      0      False
# ...

# %%
dados_combinados.query('tratamento == "com_controle"')['ativo_moa'].value_counts()
# Out:
# False    1866
# Name: ativo_moa, dtype: int64

# %%
dados_combinados.query('tratamento == "com_droga"')['ativo_moa'].value_counts()
# Out:
# True     14447
# False     7501
# Name: ativo_moa, dtype: int64

# %%
composto_principal = dados_combinados['composto'].value_counts().index[:6]
plt.figure(figsize=(12,8))
sns.boxplot(data=dados_combinados.query('composto in @composto_principal'), y='g-0', x='composto', hue='ativo_moa')

# %%
plt.figure(figsize=(12,8))
sns.boxplot(data=dados_combinados.query('composto in @composto_principal'), y='g-0', x='composto', hue='tratamento')

# %% [markdown]
# # Aula 04
#
# ###Desafio 01: Encontrar o top 10, das ações do MOA (inibidor, agonista...).
#
# ###Desafio 02: Criar a coluna eh_controle para quando na linha tratamento == com_controle.
#
# ###Desafio 03: Criar três colunas para indicar o tempo 24, 48, 72
#
# ###Desafio 04: Estudar sobre combinações de data frames (DF) https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html.
#
# ###Desafio 05: Fazer análise mais detalhada considerando tempo e dose, para comparar as distribuições (escolher uma droga e comparar com controle).
#
# ###Desafio 06: Descobrir se temos algum composto que dependendo da configuração do experimento, ativa ou não ativa algum MOA.
#
# ###Desafio 07: Descobrir se temos algum composto que dependendo da configuração do experimento, ativa MOAs diferentes.
#
# ###Desafio 08: Resumo do que você aprendeu com os dados.

# %% [markdown]
# #Desafio 01: Encontrar o top 10, das ações do MOA (inibidor, agonista...).

# %%
dados_resultados.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  n_moa  ativo_moa
# 0  id_000644bb2                            0  ...      1       True
# 1  id_000779bfc                            0  ...      0      False
# 2  id_000a6266a                            0  ...      3       True
# 3  id_0015fd391                            0  ...      0      False
# 4  id_001626bd3                            0  ...      1       True
#
# [5 rows x 209 columns]

# %%
colunas_inibidor = [col for col in dados_resultados if col.endswith('_inhibitor')]
colunas_agonista = [col for col in dados_resultados if col.endswith('_agonist')]
colunas_antagonista = [col for col in dados_resultados if col.endswith('_antagonist')]
colunas_ativador = [col for col in dados_resultados if col.endswith('_activator')]
colunas_estimulante = [col for col in dados_resultados if col.endswith('_stimulant')]

# %%
# Top 10 inibidores
dados_resultados[colunas_inibidor].sum().sort_values(ascending=False)[:11]
# Out:
# nfkb_inhibitor              832
# proteasome_inhibitor        726
# cyclooxygenase_inhibitor    435
# dna_inhibitor               402
# cdk_inhibitor               340
# egfr_inhibitor              336
# tubulin_inhibitor           316
# pdgfr_inhibitor             297
# hmgcr_inhibitor             283
# flt3_inhibitor              279
# kit_inhibitor               273
# dtype: int64

# %%
# Top 10 ativadores
dados_resultados[colunas_ativador].sum().sort_values(ascending=False)[:11]
# Out:
# potassium_channel_activator    55
# nrf2_activator                 18
# caspase_activator              18
# ampk_activator                 12
# adenylyl_cyclase_activator     12
# dtype: int64

# %%
# Top 10 agonistas
dados_resultados[colunas_agonista].sum().sort_values(ascending=False)[:11]
# Out:
# adrenergic_receptor_agonist        270
# glucocorticoid_receptor_agonist    266
# serotonin_receptor_agonist         236
# acetylcholine_receptor_agonist     190
# estrogen_receptor_agonist          158
# dopamine_receptor_agonist          121
# progesterone_receptor_agonist      119
# ppar_receptor_agonist              115
# gaba_receptor_agonist              106
# glutamate_receptor_agonist          74
# retinoid_receptor_agonist           67
# dtype: int64

# %%
# Top 10 antagonistas
dados_resultados[colunas_antagonista].sum().sort_values(ascending=False)[:11]
# Out:
# dopamine_receptor_antagonist         424
# serotonin_receptor_antagonist        404
# glutamate_receptor_antagonist        367
# adrenergic_receptor_antagonist       360
# acetylcholine_receptor_antagonist    301
# histamine_receptor_antagonist        241
# gaba_receptor_antagonist             165
# cc_chemokine_receptor_antagonist     102
# potassium_channel_antagonist          98
# opioid_receptor_antagonist            96
# adenosine_receptor_antagonist         96
# dtype: int64

# %%
# Top 10 estilumante
dados_resultados[colunas_estimulante].sum().sort_values(ascending=False)[:11]
# Out:
# apoptosis_stimulant    49
# dtype: int64

# %% [markdown]
# #Desafio 02: Criar a coluna eh_controle para quando na linha tratamento == com_controle.

# %%
dados_combinados['tratamento'].unique()
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %%
dados_combinados['eh_controle'] = (dados_combinados['tratamento'] == 'com_controle')
dados_combinados
# Out:
#                  id    tratamento  tempo  ... n_moa ativo_moa  eh_controle
# 0      id_000644bb2     com_droga     24  ...     1      True        False
# 1      id_000779bfc     com_droga     72  ...     0     False        False
# 2      id_000a6266a     com_droga     48  ...     3      True        False
# 3      id_0015fd391     com_droga     48  ...     0     False        False
# 4      id_001626bd3     com_droga     72  ...     1      True        False
# ...             ...           ...    ...  ...   ...       ...          ...
# 23809  id_fffb1ceed     com_droga     24  ...     1      True        False
# 23810  id_fffb70c0c     com_droga     24  ...     1      True        False
# 23811  id_fffc1c3f4  com_controle     48  ...     0     False         True
# 23812  id_fffcb9e7c     com_droga     24  ...     1      True        False
# 23813  id_ffffdd77b     com_droga     72  ...     0     False        False
#
# [23814 rows x 880 columns]

# %% [markdown]
# #Desafio 03: Criar três colunas para indicar o tempo 24, 48, 72

# %%
dados_combinados['tempo'].unique()
# Out:
# array([24, 72, 48])

# %%
dados_combinados['eh_24horas'] = (dados_combinados['tempo'] == 24)
dados_combinados
# Out:
#                  id    tratamento  tempo  ... ativo_moa eh_controle  eh_24horas
# 0      id_000644bb2     com_droga     24  ...      True       False        True
# 1      id_000779bfc     com_droga     72  ...     False       False       False
# 2      id_000a6266a     com_droga     48  ...      True       False       False
# 3      id_0015fd391     com_droga     48  ...     False       False       False
# 4      id_001626bd3     com_droga     72  ...      True       False       False
# ...             ...           ...    ...  ...       ...         ...         ...
# 23809  id_fffb1ceed     com_droga     24  ...      True       False        True
# 23810  id_fffb70c0c     com_droga     24  ...      True       False        True
# 23811  id_fffc1c3f4  com_controle     48  ...     False        True       False
# 23812  id_fffcb9e7c     com_droga     24  ...      True       False        True
# 23813  id_ffffdd77b     com_droga     72  ...     False       False       False
#
# ...

# %%
dados_combinados['eh_48horas'] = (dados_combinados['tempo'] == 48)
dados_combinados['eh_72horas'] = (dados_combinados['tempo'] == 72)
dados_combinados
# Out:
#                  id    tratamento  tempo  ... eh_24horas eh_48horas  eh_72horas
# 0      id_000644bb2     com_droga     24  ...       True      False       False
# 1      id_000779bfc     com_droga     72  ...      False      False        True
# 2      id_000a6266a     com_droga     48  ...      False       True       False
# 3      id_0015fd391     com_droga     48  ...      False       True       False
# 4      id_001626bd3     com_droga     72  ...      False      False        True
# ...             ...           ...    ...  ...        ...        ...         ...
# 23809  id_fffb1ceed     com_droga     24  ...       True      False       False
# 23810  id_fffb70c0c     com_droga     24  ...       True      False       False
# 23811  id_fffc1c3f4  com_controle     48  ...      False       True       False
# 23812  id_fffcb9e7c     com_droga     24  ...       True      False       False
# 23813  id_ffffdd77b     com_droga     72  ...      False      False        True
#
# ...

# %% [markdown]
# #Desafio 04: Estudar sobre combinações de data frames (DF) https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html.

# %% [markdown]
# #Desafio 05: Fazer análise mais detalhada considerando tempo e dose, para comparar as distribuições (escolher uma droga e comparar com controle).

# %%
principal_composto = dados_combinados['composto'].describe()[2]
plt.figure(figsize=(12,8))
sns.boxplot(data=dados_combinados.query('composto == @principal_composto'), y='g-0', x='composto', hue='tempo')

# %% [markdown]
# #Desafio 06: Descobrir se temos algum composto que dependendo da configuração do experimento, ativa ou não ativa algum MOA.

# %%
cinco_principais_compostos = dados_combinados['composto'].value_counts()[:5].index.to_list()
cinco_principais_compostos
# Out:
# ['cacb2b860', '87d714366', '9f80f3f77', '8b87a7a83', '5628cb3ee']

# %%
# 1° Composto com maior frequência, ativação do MOA
dados_combinados.query('composto == @cinco_principais_compostos[0] and ativo_moa')
# Out:
# Empty DataFrame
# Columns: [id, tratamento, tempo, dose, composto, g-0, g-1, g-2, g-3, g-4, g-5, g-6, g-7, g-8, g-9, g-10, g-11, g-12, g-13, g-14, g-15, g-16, g-17, g-18, g-19, g-20, g-21, g-22, g-23, g-24, g-25, g-26, g-27, g-28, g-29, g-30, g-31, g-32, g-33, g-34, g-35, g-36, g-37, g-38, g-39, g-40, g-41, g-42, g-43, g-44, g-45, g-46, g-47, g-48, g-49, g-50, g-51, g-52, g-53, g-54, g-55, g-56, g-57, g-58, g-59, g-60, g-61, g-62, g-63, g-64, g-65, g-66, g-67, g-68, g-69, g-70, g-71, g-72, g-73, g-74, g-75, g-76, g-77, g-78, g-79, g-80, g-81, g-82, g-83, g-84, g-85, g-86, g-87, g-88, g-89, g-90, g-91, g-92, g-93, g-94, ...]
# Index: []
#
# [0 rows x 883 columns]

# %%
# 2° composto com maior frequência, ativação do MOA:
dados_combinados.query('composto == @cinco_principais_compostos[1] and ativo_moa')
# Out:
#                  id tratamento  tempo  ... eh_24horas eh_48horas  eh_72horas
# 16     id_002fb9c19  com_droga     48  ...      False       True       False
# 76     id_00cf039a7  com_droga     48  ...      False       True       False
# 119    id_01534c4ee  com_droga     72  ...      False      False        True
# 209    id_0236e3425  com_droga     72  ...      False      False        True
# 218    id_024a52260  com_droga     24  ...       True      False       False
# ...             ...        ...    ...  ...        ...        ...         ...
# 23680  id_fe8abffe0  com_droga     72  ...      False      False        True
# 23727  id_ff1d43f96  com_droga     24  ...       True      False       False
# 23776  id_ff9d0a022  com_droga     24  ...       True      False       False
# 23791  id_ffd1fd119  com_droga     72  ...      False      False        True
# 23802  id_fff3976bd  com_droga     24  ...       True      False       False
#
# [718 rows x 883 columns]

# %%
# 3° composto com maior frequência, ativação do MOA:
dados_combinados.query('composto == @cinco_principais_compostos[2] and ativo_moa')
# Out:
#                  id tratamento  tempo  ... eh_24horas eh_48horas  eh_72horas
# 75     id_00ceee87f  com_droga     24  ...       True      False       False
# 251    id_02945c933  com_droga     48  ...      False       True       False
# 337    id_03a148573  com_droga     48  ...      False       True       False
# 355    id_03d57c47a  com_droga     24  ...       True      False       False
# 404    id_04495c8c8  com_droga     24  ...       True      False       False
# ...             ...        ...    ...  ...        ...        ...         ...
# 23400  id_fb9af8d4b  com_droga     24  ...       True      False       False
# 23604  id_fd9b2b44a  com_droga     72  ...      False      False        True
# 23675  id_fe7394162  com_droga     24  ...       True      False       False
# 23762  id_ff78a40f0  com_droga     24  ...       True      False       False
# 23774  id_ff96bcd4d  com_droga     48  ...      False       True       False
#
# [246 rows x 883 columns]

# %% [markdown]
# #Desafio 07: Descobrir se temos algum composto que dependendo da configuração do experimento, ativa MOAs diferentes.

# %%
# 1° Composto com maior frequência, avaliação de ativação n_moa
dados_combinados.query('composto == @cinco_principais_compostos[0] and n_moa > 1')
# Out:
# Empty DataFrame
# Columns: [id, tratamento, tempo, dose, composto, g-0, g-1, g-2, g-3, g-4, g-5, g-6, g-7, g-8, g-9, g-10, g-11, g-12, g-13, g-14, g-15, g-16, g-17, g-18, g-19, g-20, g-21, g-22, g-23, g-24, g-25, g-26, g-27, g-28, g-29, g-30, g-31, g-32, g-33, g-34, g-35, g-36, g-37, g-38, g-39, g-40, g-41, g-42, g-43, g-44, g-45, g-46, g-47, g-48, g-49, g-50, g-51, g-52, g-53, g-54, g-55, g-56, g-57, g-58, g-59, g-60, g-61, g-62, g-63, g-64, g-65, g-66, g-67, g-68, g-69, g-70, g-71, g-72, g-73, g-74, g-75, g-76, g-77, g-78, g-79, g-80, g-81, g-82, g-83, g-84, g-85, g-86, g-87, g-88, g-89, g-90, g-91, g-92, g-93, g-94, ...]
# Index: []
#
# [0 rows x 883 columns]

# %%
# 2° Composto com maior frequência, avaliação de ativação n_moa
dados_combinados.query('composto == @cinco_principais_compostos[1] and n_moa > 1')
# Out:
#                  id tratamento  tempo  ... eh_24horas eh_48horas  eh_72horas
# 16     id_002fb9c19  com_droga     48  ...      False       True       False
# 76     id_00cf039a7  com_droga     48  ...      False       True       False
# 119    id_01534c4ee  com_droga     72  ...      False      False        True
# 209    id_0236e3425  com_droga     72  ...      False      False        True
# 218    id_024a52260  com_droga     24  ...       True      False       False
# ...             ...        ...    ...  ...        ...        ...         ...
# 23680  id_fe8abffe0  com_droga     72  ...      False      False        True
# 23727  id_ff1d43f96  com_droga     24  ...       True      False       False
# 23776  id_ff9d0a022  com_droga     24  ...       True      False       False
# 23791  id_ffd1fd119  com_droga     72  ...      False      False        True
# 23802  id_fff3976bd  com_droga     24  ...       True      False       False
#
# [718 rows x 883 columns]

# %%
# 3° Composto com maior frequência, avaliação de ativação n_moa
dados_combinados.query('composto == @cinco_principais_compostos[2] and n_moa > 1')
# Out:
# Empty DataFrame
# Columns: [id, tratamento, tempo, dose, composto, g-0, g-1, g-2, g-3, g-4, g-5, g-6, g-7, g-8, g-9, g-10, g-11, g-12, g-13, g-14, g-15, g-16, g-17, g-18, g-19, g-20, g-21, g-22, g-23, g-24, g-25, g-26, g-27, g-28, g-29, g-30, g-31, g-32, g-33, g-34, g-35, g-36, g-37, g-38, g-39, g-40, g-41, g-42, g-43, g-44, g-45, g-46, g-47, g-48, g-49, g-50, g-51, g-52, g-53, g-54, g-55, g-56, g-57, g-58, g-59, g-60, g-61, g-62, g-63, g-64, g-65, g-66, g-67, g-68, g-69, g-70, g-71, g-72, g-73, g-74, g-75, g-76, g-77, g-78, g-79, g-80, g-81, g-82, g-83, g-84, g-85, g-86, g-87, g-88, g-89, g-90, g-91, g-92, g-93, g-94, ...]
# Index: []
#
# [0 rows x 883 columns]

# %% [markdown]
# #Desafio 08: Resumo do que você aprendeu com os dados.
#
# - Fatiar os dados por termos nas colunas;
# - Criar novas colunas com valores calculados;
# - Avançamos nos conhecimentos do boxplot;
# - Obter maior frequência dos resultados;
# - Aprofundamento no conhecimento do merge e combinação de bases;
# - Aprofundamento na avaliação dos dados em correlações simples.
